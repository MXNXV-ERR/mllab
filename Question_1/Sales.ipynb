# %% [markdown]
# # Question 1
#
# [Kaggle Dataset link](https://www.kaggle.com/datasets/ashydv/advertising-dataset/download?datasetVersionNumber=1)

# %% [markdown]
# # Univariate

# %% [markdown]
# Importing dataset

# %%
import pandas as pd
df=pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# Plotting Advertising Media vs Sales

# %%
import matplotlib.pyplot as plt
graphSheet = plt.figure(figsize=(15,10))
graphSheet.add_subplot(3,3,1)
plt.scatter(df['TV'],df['Sales'])
plt.xlabel("Money Spent on TV")
plt.ylabel("Sales")
graphSheet.add_subplot(3,3,2)
plt.scatter(df['Radio'],df['Sales'],c='orange')
plt.xlabel("Money Spent on Radio")
plt.ylabel("Sales")
graphSheet.add_subplot(3,3,3)
plt.scatter(df['Newspaper'],df['Sales'],c='teal')
plt.xlabel("Money Spent on Newspaper")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# Importing and fitting model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
import numpy as np
graphSheet = plt.figure(figsize=(15,10))
def linReg(x,y,z):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
    x_train = x_train.to_numpy().reshape(-1,1)
    x_test = x_test.to_numpy().reshape(-1,1)
    y_train = y_train.to_numpy().reshape(-1,1)
    y_test = y_test.to_numpy().reshape(-1,1)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    print("Coeff=",lr.coef_[0][0],"Intercept=",lr.intercept_[0])
    pred = lr.predict(x_test)
    rmse=np.sqrt(mean_squared_error(y_test,pred))
    print("Root mean sqr err=",rmse)
    # graphSheet.add_subplot(2,2,n)
    fig, ax = plt.subplots()
    ax.scatter(x_train,y_train)
    ax.scatter(x_test,y_test)
    ax.set_xlabel("Money Spent on")
    ax.set_ylabel("Sales")
    ax.set_title(z)
    ax.plot(x_test,pred,c='gold')
    plt.show()

# %%
#graphSheet.add_subplot(2,2,1)
linReg(df['TV'],df['Sales'],"Tv vs Sales")
#graphSheet.add_subplot(2,2,2)
linReg(df['Radio'],df['Sales'],"Radio vs Sales")
linReg(df['Newspaper'],df['Sales'],"Newspaper vs Sales")
# Out:
# Coeff= 0.05414229982725613 Intercept= 7.1620364669765895
# Root mean sqr err= 2.209167300341713
# Coeff= 0.10783653983199055 Intercept= 12.998053058690614
# Root mean sqr err= 5.604036066357686
# Coeff= 0.02676055379608803 Intercept= 14.718546571866515
# Root mean sqr err= 5.940801970910305

# %% [markdown]
# # Multivariate

# %%
linReg(df['Newspaper'],df['Sales'])
linReg(df['TV'],df['Sales'])
# Out:
# Coeff= 0.03724510241746705 Intercept= 14.32213953019128
# Root mean sqr err= 5.234470860601701
# Coeff= 0.055187539928050276 Intercept= 6.984392801930384
# Root mean sqr err= 2.4629130322242876
